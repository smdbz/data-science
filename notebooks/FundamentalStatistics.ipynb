# %% [markdown]
# # Fundamental Statistics

# %% [markdown]
# ## 1. What is Statistics?
#
# By the end of this section you will know what Statistics is, what Descriptive Statistics is and what Inferential Statistics is.
#
# Statistics is the collection, analysis and presentation of data.

# %% [markdown]
# ## 2. Hypothesis Tests
#
# What is it? What are the most common tests?
# t tests, ANOVA
# Difference between parametric and non-parametric tests

# %% [markdown]
# ## 3. Correlation Analysis and Regression Analysis

# %% [markdown]
# ## 4. Cluster Analysis
