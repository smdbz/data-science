# %%
import kagglehub
import pandas as pd

# %%
kagglehub.dataset_download("fedesoriano/heart-failure-prediction", path="heart.csv")
# Out:
# 'C:\\Users\\zak\\.cache\\kagglehub\\datasets\\fedesoriano\\heart-failure-prediction\\versions\\1\\heart.csv'

# %%
df = pd.read_csv(
    'C:\\Users\\zak\\.cache\\kagglehub\\datasets\\fedesoriano\\heart-failure-prediction\\versions\\1\\heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ## Formalising Machine Learning Approach
#
# Let's formalise a general approach to machine learning that can be reused in other projects.
#
# ```python
# from sklearn.model_selection import train_test_split
# from sklearn.pipeline import Pipeline
# from sklearn.tree import DecisionTreeClassifier
# ```

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[

])
