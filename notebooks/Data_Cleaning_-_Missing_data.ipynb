# %% [markdown]
# ## Cleaning Data -> Missing Data

# %%
## Import packages
import pandas as pd, numpy as np
from scipy import stats

# %% [markdown]
# ## Demo of how missing data can cause errors

# %%
np.mean([5, 10, 15, None])
# Out:
# np.float64(7.5)

# %%
diabetes = pd.read_csv(r'c:\Users\Xps\Documents\Tutor\Python\Cleaning data\diabetes.csv')
diabetes['Diastolic_BP'].corr(diabetes['Glucose'])
# Out:
# np.float64(0.2231917782495421)

# %%
stats.pearsonr(diabetes['Diastolic_BP'], diabetes['Glucose'])
# Out:
# PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))

# %% [markdown]
# ![Why do we clean data 2.png](<attachment:Why do we clean data 2.png>)

# %%
np.mean(np.square([-5,5,-5,5])) ### MSE - Mean squared error
np.sqrt(np.mean(np.square([-5,5,-5,5]))) ## RMSE - Root Mean Squared Error - RMSE
# Out:
# np.float64(5.0)

# %% [markdown]
# ## Dealing with missing data
#
# - MAR: Missing at Random - the good guys
#     - Not coming from a systematic error
#     - Low in proportion
#     - Lack of/no apparent correlation to other variables in terms of missing data
#
#     - Actions available after identification = Imputation and Dropping
#
# - MNAR - Missing not at random - the bad guys
#     - Systematic error involved
#     - High proportion
#     - Strong evidence of correlation
#
#     - Actions available after identification = Imputation
#
# - MCAR: Missing Completely at Random
#     - A low version of MAR

# %%
diabetes.isnull()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 0       False    False         False      False           True  False
# 1       False    False         False      False           True  False
# 2       False    False         False       True           True  False
# 3       False    False         False      False          False  False
# 4       False    False         False      False          False  False
# ..        ...      ...           ...        ...            ...    ...
# 763     False    False         False      False          False  False
# 764     False    False         False      False           True  False
# 765     False    False         False      False          False  False
# 766     False    False         False       True           True  False
# 767     False    False         False      False           True  False
#
#      Diabetes_Pedigree    Age  Class
# 0                False  False  False
# 1                False  False  False
# ...

# %%
diabetes.isnull().sum()
round((diabetes.isnull().mean())*100,2)
# Out:
# Pregnant              0.00
# Glucose               0.65
# Diastolic_BP          4.56
# Skin_Fold            29.56
# Serum_Insulin        48.70
# BMI                   1.43
# Diabetes_Pedigree     0.00
# Age                   0.00
# Class                 0.00
# dtype: float64

# %%
import matplotlib.pyplot as plt, seaborn as sns
missing_proportions  = round((diabetes.isnull().mean())*100,2).reset_index()
sns.barplot(missing_proportions, y='index', x=0)
plt.xlim((0,100))
# Out:
# (0.0, 100.0)

# %%
filled_data  = round((diabetes.notnull().mean())*100,2).reset_index()
sns.barplot(filled_data, y='index', x=0)
plt.xlim((0,100))
# Out:
# (0.0, 100.0)

# %%
import missingno as msno
msno.bar(diabetes)
# Out:
# <Axes: >

# %%
msno.matrix(diabetes)
# Out:
# <Axes: >

# %% [markdown]
# ## For next time
# - Work on other dataset - choose two variables (numerical) and check their correlation with scipy and .corr
# - Produce the manual charts we made earlier
# - Use the MSNO package to visualise
# - Do a bit of research on types of missing data
