# %% [markdown]
# Pseudo-code workflow.
#
# Current understanding of the workflow:
#
# There are 2 types of classes in the package:
# "project class" and "tutor class"
#
# 1. Project classes
#     - Project
#     - Model
#     - EDA
#     - Diagnostics
#     - Submit
# 2. Tutor classes
#     - BaseTutor
#     -
#     - EDATutor
#         -
#     - DiagnosticsTutor
#     - SubmitTutor
# Project classes keep track of certain information and/or states of the project.
# The project classes use tutor classes, built from a base tutor class, to move the project forward.
# -   Called tutor classes because they should teach/remind the user of the
#
#
#
# ```python
# my_project = Project() # I think only initalised once a the beginning of the jupyter notebook
#
#
# ```
