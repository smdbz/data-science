# %% [markdown]
# Notebook to test the workflow of ds-tutor. What follows is what I think a typical workflow using the ds-tutor package should be like.

# %% [markdown]
# # Diabetes Prediction
#
# Diabetes Binary Classification with

# %%
from ds_tutor import ProjectContext, ExperimentConfig, MissingDataTutor, SkewnessTutor, PipelineRunner
import pandas as pd

# %%
diabetes = pd.read_csv(r'../../data/diabetes.csv')

# %%
diabetes_classification = ProjectContext('diabetes_classification', diabetes, 'Class')

# %%
diabetes_classification

# %%
diabetes_classification.initialize()
# Out:
# [SYSTEM] Context Initialized. Target leakage prevented.
# [MATH] Naive Baseline E[Y] = 0.35
